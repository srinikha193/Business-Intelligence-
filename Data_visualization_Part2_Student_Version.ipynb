# %% [markdown]
# <a href="https://colab.research.google.com/github/srinikha193/Data-Analysis-Course-Work/blob/main/Data_visualization_Part2_Student_Version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization (Part 2)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #### Import required packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Example 1: Boston Housing Data

# %% [markdown]
# The Boston Housing data contain information on census tracts in Boston for
# which several measurements are taken (e.g., crime rate, pupil/teacher ratio). It
# has 14 variables. A description of each variable is given in the table below and a
# sample of the first nine records is shown in the following DataFrame. In addition to the original 13 variables, the dataset also contains the additional variable CAT.MEDV, which
# has been created by categorizing median value (MEDV) into two categories:
# high and low.<br>
# ##We can consider three possible tasks:
# 1. A supervised predictive task, where the outcome variable of interest is
# the median value of a home in the tract (MEDV).
# 2. A supervised classification task, where the outcome variable of interest is
# the binary variable CAT.MEDV that indicates whether the home value
# is above or below $30,000.
# 3. An unsupervised task, where the goal is to cluster census tracts.
# Note: MEDV and CAT.MEDV should not be used together in any of the three cases.

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %%
# Importing the dataset
housing_df = pd.read_csv('BostonHousing.csv')
housing_df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#    LSTAT  MEDV  CAT. MEDV
# 0   4.98  24.0          0
# 1   9.14  21.6          0
# 2   4.03  34.7          1
# ...

# %%
# rename CAT. MEDV column for easier data handling
housing_df = housing_df.rename(columns={'CAT. MEDV': 'CAT_MEDV'})
housing_df.head(9)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
#
#    LSTAT  MEDV  CAT_MEDV
# 0   4.98  24.0         0
# 1   9.14  21.6         0
# 2   4.03  34.7         1
# 3   2.94  33.4         1
# 4   5.33  36.2         1
# 5   5.21  28.7         0
# ...

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# In supervised learning, there will be more focus on
# the outcome variable. In scatter plots, the outcome variable is typically associated
# with the x or y-axis. In unsupervised learning (for the purpose of data reduction
# or clustering), basic plots that convey relationships (such as scatter plots) are preferred.

# %%
housing_df.plot.scatter(x='LSTAT', y='MEDV', legend=False)
# Out:
# <Axes: xlabel='LSTAT', ylabel='MEDV'>

# %%
# Another way of creating the same plot with different color
# Set the color of the points in the scatterplot and draw as open circles.
fig, ax = plt.subplots()

ax.scatter(housing_df.LSTAT, housing_df.MEDV, color='C2', facecolor='none')
# C2 : green
# facecolor='none': empty circles
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')

# %% [markdown]
# For unsupervised learning, this particular scatter plot helps study the association
# between two numerical variables in terms of information overlap as well as
# identifying clusters of observations.

# %% [markdown]
# ### Bar Plot

# %% [markdown]
# Bar charts are useful for comparing a single statistic (e.g., average, count,
# percentage) across groups. The height of the bar (or length in a horizontal
# display) represents the value of the statistic, and different bars correspond to
# different groups. Two bar chart examples are shown below. <br> <br>
# In each, separate
# bars are used to denote homes in Boston that are near the Charles River vs. those
# that are not (thereby comparing the two categories of CHAS). The chart with
# the numerical output MEDV uses the average MEDV on the y-
# axis. This supports the predictive task: the numerical outcome is on the y-axis
# and the x-axis is used for a potential categorical predictor.
#
# (Note that the x-axis
# on a bar chart must be used only for categorical variables, because the order of
# bars in a bar chart should be interchangeable.)

# %%
barplot = housing_df.groupby('CHAS').mean().MEDV.plot(kind='bar')
barplot.set_ylabel('Avg. MEDV')
# Out:
# Text(0, 0.5, 'Avg. MEDV')

# %%
# same bar plot with different color
barplot = housing_df.groupby('CHAS').mean().MEDV.plot(kind='bar',color=['C5', 'C1'] )
barplot.set_ylabel('Avg. MEDV')
# Out:
# Text(0, 0.5, 'Avg. MEDV')

# %% [markdown]
# This bar chart can be used for a classification task, where the y-axis indicates the percent of tracts with median value above 30K dollars
# and the x-axis is a binary variable indicating proximity to the Charles. This
# graph shows us that the tracts bordering the Charles are much more likely to
# have median values above 30K dollars.

# %%
dataForPlot = housing_df.groupby('CHAS').mean()['CAT_MEDV'] * 100
barplot2 = dataForPlot.plot(kind='bar')
barplot2.set_ylabel('% of CAT.MEDV')
# Out:
# Text(0, 0.5, '% of CAT.MEDV')

# %%
# You can change the color for this one too:
dataForPlot = housing_df.groupby('CHAS').mean()['CAT_MEDV'] * 100
barplot2 = dataForPlot.plot(kind='bar', color=['C5', 'C1'])
barplot2.set_ylabel('% of CAT.MEDV')
# Out:
# Text(0, 0.5, '% of CAT.MEDV')

# %% [markdown]
# ### Histogram
#
# Whereas bar charts can only use a single aggregation,
# histograms (and boxplots) display the entire distribution of a numerical variable.
#
#
# Distribution plots are useful in supervised learning for determining potential
# data mining methods and variable transformations. For example, skewed numerical
# variables might warrant transformation (e.g., moving to a logarithmic scale)
# if used in methods that assume normality (e.g., linear regression, discriminant
# analysis).
# A histogram represents the frequencies of all x values with a series of vertical
# connected bars. Let's look at the following plot as an example:

# %%
ax = housing_df.MEDV.hist()
ax.set_xlabel('MEDV')
ax.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# In this histogram, there are over 150
# tracts where the median value (MEDV) is between 19K-22K dollars.

# %% [markdown]
# ### Boxplot
#
# Boxplots are also effective for comparing subgroups by generating side-by-side
# boxplots, or for looking at distributions over time by creating a series of boxplots.
#
#
# The box encloses 50% of the data—for example, in the following boxplot, the right-hand box shows that half of the tracts have median values (MEDV) between 21,000–
# 33,000 dollars. The horizontal line inside the box represents the median (50th percentile).
# The top and bottom of the box represent the 75th and 25th percentiles,
# respectively. Lines extending above and below the box cover the rest of the data
# range; outliers may be depicted as points or circles.

# %%
ax = housing_df.boxplot(column='MEDV', by='CHAS')
ax.set_ylabel('MEDV')
plt.suptitle('')  # Suppress the titles
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %% [markdown]
# # Exercises

# %% [markdown]
# 1. Create side by side boxplots for CAT.MEDV variable against the following 4 variables: NOX, LSTAT, PTRATIO, and INDUS.
#
# Expected output:

# %%
fig,axes=plt.subplots(1,4,figsize=(8,6))
housing_df.boxplot(column='NOX', by='CAT_MEDV', ax = axes[0])
housing_df.boxplot(column='LSTAT', by='CAT_MEDV', ax = axes[1])
housing_df.boxplot(column='PTRATIO', by='CAT_MEDV', ax = axes[3])
housing_df.boxplot(column='INDUS', by='CAT_MEDV', ax = axes[2])
plt.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %% [markdown]
# 2. Create a scatter plot for LSTAT vs NOX.
#
# Expected output:

# %%
housing_df.plot.scatter(x='LSTAT', y='NOX',
c=['C3' if c==1 else 'C8' for c in housing_df.CAT_MEDV])
# Out:
# <Axes: xlabel='LSTAT', ylabel='NOX'>

# %% [markdown]
# 3. Create two side by side scatter plots for CRIM vs MEDV. Use the original values in the first plot but in the second plot use the log transformation.
# Hint: for log transformation use logx and/or logy arguments. These arguments are set to False by default. You need to set them to True. The expected output is shown below.

# %%
fig,axes=plt.subplots(1,2,figsize=(8,3))
housing_df.plot.scatter(x='CRIM',y='MEDV',ax=axes[0])
housing_df.plot.scatter(x='CRIM',y='MEDV',logx=True,logy=True,ax=axes[1])
plt.suptitle('')
# Out:
# Text(0.5, 0.98, '')

# %% [markdown]
# Changing the scale in a display can enhance the plot and illuminate
# relationships. For example, in Figure 3.8, we see the effect of changing
# both axes of the scatter plot (top) and the y-axis of a boxplot (bottom) to logarithmic
# (log) scale. Whereas the original plots (left) are hard to understand, the
# patterns become visible in log scale (right). In the histograms, the nature of the
# relationship between MEDV and CRIM is hard to determine in the original
# scale, because too many of the points are “crowded” near the y-axis. The rescaling
# removes this crowding and allows a better view of the linear relationship
# between the two log-scaled variables (indicating a log–log relationship).

# %% [markdown]
# ## Heatmap

# %%
corr = housing_df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)
# Out:
# <Axes: >

# %%
# Include information about values
fig, ax = plt.subplots(figsize = (11, 7))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True )
# Out:
# <Axes: >

# %% [markdown]
# ## Time Series

# %% [markdown]
# # Example 2: Ridership on Amtrak Trains
# Amtrak, a US railway company, routinely collects data on ridership. Here
# we focus on forecasting future ridership using the series of monthly ridership
# between January 1991 and March 2004. Hence our task here is (numerical) time series forecasting. In this dataset, Ridership is the number of passengers ( in thousands)

# %% [markdown]
# Load the Amtrak data and convert them to be suitable for time series analysis

# %%
Amtrak_df = pd.read_csv('Amtrak.csv')
Amtrak_df.head(10)
# Out:
#         Month  Ridership
# 0  01/01/1991   1708.917
# 1  01/02/1991   1620.586
# 2  01/03/1991   1972.715
# 3  01/04/1991   1811.665
# 4  01/05/1991   1974.964
# 5  01/06/1991   1862.356
# 6  01/07/1991   1939.860
# 7  01/08/1991   2013.264
# 8  01/09/1991   1595.657
# 9  01/10/1991   1724.924

# %%
Amtrak_df['Date'] = pd.to_datetime(Amtrak_df.Month, format='%d/%m/%Y')
Amtrak_df.head(10)
# Out:
#         Month  Ridership       Date
# 0  01/01/1991   1708.917 1991-01-01
# 1  01/02/1991   1620.586 1991-02-01
# 2  01/03/1991   1972.715 1991-03-01
# 3  01/04/1991   1811.665 1991-04-01
# 4  01/05/1991   1974.964 1991-05-01
# 5  01/06/1991   1862.356 1991-06-01
# 6  01/07/1991   1939.860 1991-07-01
# 7  01/08/1991   2013.264 1991-08-01
# 8  01/09/1991   1595.657 1991-09-01
# 9  01/10/1991   1724.924 1991-10-01

# %%
ridership_ts = pd.Series(Amtrak_df.Ridership.values, index=Amtrak_df.Date)
ridership_ts
# Out:
# Date
# 1991-01-01    1708.917
# 1991-02-01    1620.586
# 1991-03-01    1972.715
# 1991-04-01    1811.665
# 1991-05-01    1974.964
#                 ...
# 2003-11-01    2076.054
# 2003-12-01    2140.677
# 2004-01-01    1831.508
# 2004-02-01    1838.006
# 2004-03-01    2132.446
# Length: 159, dtype: float64

# %%
ridership_ts.plot(ylim=[1300, 2300], legend=False, figsize=[5, 3])
plt.xlabel('Year')  # set x-axis label
plt.ylabel('Ridership (in 000s)')  # set y-axis label
# Out:
# Text(0, 0.5, 'Ridership (in 000s)')

# %%
# alternative plot with matplotlib
plt.plot(ridership_ts.index, ridership_ts)
plt.xlabel('Year')  # set x-axis label
plt.ylabel('Ridership (in 000s)')  # set y-axis label
# Out:
# Text(0, 0.5, 'Ridership (in 000s)')

# %% [markdown]
# The chart above displays a line chart for the time series of
# monthly railway passengers on Amtrak. Line graphs are used primarily for showing
# time series. The choice of time frame to plot, as well as the temporal scale,
# should depend on the horizon of the forecasting task and on the nature of the
# data.

# %% [markdown]
# ## Zooming and Panning
# The ability to zoom in and out of certain areas of
# the data on a plot is important for revealing patterns and outliers. We are often
# interested in more detail on areas of dense information or of special interest.
# Panning refers to the operation of moving the zoom window to other areas
# (popular in mapping applications such as Google Maps). An example of zooming
# is shown below, where the ridership series is
# zoomed in to the first two years of the series.

# %%
Amtrak_df.set_index('Date', inplace=True)


# Zoom in 2-year period 1/1/1991 to 12/1/1992
ridership_2yrs = Amtrak_df.loc['1991-01-01':'1992-12-01']
ax = ridership_2yrs.plot(ylim=[1300, 2300], legend=False)
ax.set_xlabel('Year')  # set x-axis label
ax.set_ylabel('Ridership (in 000s)')  # set y-axis label
# Out:
# Text(0, 0.5, 'Ridership (in 000s)')

# %% [markdown]
# # Source:
# Data Mining for Business Analytics: Concepts, Techniques, and Applications in Python (First Edition) Galit Shmueli, Peter C. Bruce, Peter Gedeck, and Nitin R. Patel. 2019.
